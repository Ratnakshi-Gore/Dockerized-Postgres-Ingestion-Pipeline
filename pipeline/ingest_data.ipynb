# %%
import pandas as pd

# %%
pd.__file__
# Out:
# 'C:\\Users\\Meow\\Desktop\\Data Science\\Docker datatalks workshop\\pipeline\\.venv\\Lib\\site-packages\\pandas\\__init__.py'

# %%
taxi = pd.read_csv('https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-06.csv.gz')
# Out:
# C:\Users\Meow\AppData\Local\Temp\ipykernel_27952\3549462040.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   taxi = pd.read_csv('https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-06.csv.gz')

# %%
len(taxi)
# Out:
# 2834264

# %%
taxi.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2021-06-01 00:13:26   2021-06-01 00:17:14              1.0
# 1       1.0  2021-06-01 00:32:23   2021-06-01 01:07:04              1.0
# 2       1.0  2021-06-01 00:12:15   2021-06-01 00:15:28              0.0
# 3       1.0  2021-06-01 00:35:00   2021-06-01 00:53:17              0.0
# 4       2.0  2021-06-01 00:31:01   2021-06-01 00:52:27              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.90         1.0                  N           186            50
# 1          23.00         1.0                  N           132            18
# 2           0.90         1.0                  N           138            70
# 3          11.20         1.0                  N           138           189
# 4           9.49         1.0                  N           138           142
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0           1.0          5.0   3.00      0.5        2.20          0.00
# 1           2.0         61.5   1.75      0.5        0.00          6.55
# 2           2.0          5.0   1.75      0.5        0.00          0.00
# 3           1.0         31.5   1.75      0.5        8.50          0.00
# 4           1.0         28.5   0.50      0.5        7.77          6.55
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                    0.3         11.00                   2.5
# 1                    0.3         70.60                   0.0
# 2                    0.3          7.55                   0.0
# 3                    0.3         42.55                   0.0
# 4                    0.3         47.87                   2.5

# %%
taxi.dtypes
# Out:
# VendorID                 float64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count          float64
# trip_distance            float64
# RatecodeID               float64
# store_and_fwd_flag        object
# PULocationID               int64
# DOLocationID               int64
# payment_type             float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# dtype: object

# %%
dtype = {
    "VendorID": "Int64",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "congestion_surcharge": "float64"
}

parse_dates = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]

# %%
taxi = pd.read_csv('https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-06.csv.gz',
                   dtype=dtype, 
                   parse_dates=parse_dates)

# %%
taxi.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-06-01 00:13:26   2021-06-01 00:17:14                1
# 1         1  2021-06-01 00:32:23   2021-06-01 01:07:04                1
# 2         1  2021-06-01 00:12:15   2021-06-01 00:15:28                0
# 3         1  2021-06-01 00:35:00   2021-06-01 00:53:17                0
# 4         2  2021-06-01 00:31:01   2021-06-01 00:52:27                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.90           1                  N           186            50
# 1          23.00           1                  N           132            18
# 2           0.90           1                  N           138            70
# 3          11.20           1                  N           138           189
# 4           9.49           1                  N           138           142
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1          5.0   3.00      0.5        2.20          0.00
# 1             2         61.5   1.75      0.5        0.00          6.55
# 2             2          5.0   1.75      0.5        0.00          0.00
# 3             1         31.5   1.75      0.5        8.50          0.00
# 4             1         28.5   0.50      0.5        7.77          6.55
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                    0.3         11.00                   2.5
# 1                    0.3         70.60                   0.0
# 2                    0.3          7.55                   0.0
# 3                    0.3         42.55                   0.0
# 4                    0.3         47.87                   2.5

# %%
taxi.dtypes
# Out:
# VendorID                          Int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   Int64
# trip_distance                   float64
# RatecodeID                        Int64
# store_and_fwd_flag       string[python]
# PULocationID                      Int64
# DOLocationID                      Int64
# payment_type                      Int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# dtype: object

# %%
# !uv add sqlalchemy
# Out:
# Resolved 120 packages in 2ms
# Audited 31 packages in 383ms

# %%
# !uv add psycopg2-binary
# Out:
# Resolved 120 packages in 1ms
# Audited 31 packages in 3ms

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql://root:root@localhost:5433/ny_taxi")

# %%
taxi.head(0).to_sql(name='yellow_taxi_data',con=engine, if_exists='replace')
# Out:
# 0

# %%
print(pd.io.sql.get_schema(taxi, name='yellow_taxi-data',con=engine))
# Out:
# CREATE TABLE "yellow_taxi-data" (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv(
    'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-06.csv.gz',
    dtype=dtype,
    parse_dates=parse_dates,
    iterator=True,
    chunksize=100000,
)

# %%
taxi = next(df_iter)

# %%
taxi
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2021-06-01 00:13:26   2021-06-01 00:17:14                1
# 1             1  2021-06-01 00:32:23   2021-06-01 01:07:04                1
# 2             1  2021-06-01 00:12:15   2021-06-01 00:15:28                0
# 3             1  2021-06-01 00:35:00   2021-06-01 00:53:17                0
# 4             2  2021-06-01 00:31:01   2021-06-01 00:52:27                1
# ...         ...                  ...                   ...              ...
# 99995         1  2021-06-02 10:37:29   2021-06-02 10:43:55                1
# 99996         1  2021-06-02 10:58:28   2021-06-02 11:57:24                2
# 99997         2  2021-06-02 10:44:39   2021-06-02 10:58:20                1
# 99998         2  2021-06-02 10:21:29   2021-06-02 10:34:24                1
# 99999         2  2021-06-02 10:36:28   2021-06-02 10:45:44                1
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0               0.90           1                  N           186
# 1              23.00           1                  N           132
# 2               0.90           1                  N           138
# 3              11.20           1                  N           138
# 4               9.49           1                  N           138
# ...              ...         ...                ...           ...
# 99995           1.50           1                  N           162
# 99996          17.00           2                  N           230
# 99997           0.91           1                  N           236
# 99998           3.86           1                  N           151
# 99999           1.38           1                  N            48
#
#        DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                50             1          5.0   3.00      0.5        2.20
# 1                18             2         61.5   1.75      0.5        0.00
# 2                70             2          5.0   1.75      0.5        0.00
# 3               189             1         31.5   1.75      0.5        8.50
# 4               142             1         28.5   0.50      0.5        7.77
# ...             ...           ...          ...    ...      ...         ...
# 99995           170             1          7.0   2.50      0.5        2.05
# 99996           132             1         52.0   2.50      0.5        4.70
# 99997           236             1          9.5   0.00      0.5        1.54
# 99998            48             1         14.0   0.00      0.5        3.46
# 99999           239             1          8.0   0.00      0.5        0.00
#
#        tolls_amount  improvement_surcharge  total_amount  congestion_surcharge
# 0              0.00                    0.3         11.00                   2.5
# 1              6.55                    0.3         70.60                   0.0
# 2              0.00                    0.3          7.55                   0.0
# 3              0.00                    0.3         42.55                   0.0
# 4              6.55                    0.3         47.87                   2.5
# ...             ...                    ...           ...                   ...
# 99995          0.00                    0.3         12.35                   2.5
# 99996          0.00                    0.3         60.00                   2.5
# 99997          0.00                    0.3         14.34                   2.5
# 99998          0.00                    0.3         20.76                   2.5
# 99999          0.00                    0.3         11.30                   2.5
#
# [100000 rows x 18 columns]

# %%
taxi = next(df_iter)

# %%
taxi
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 100000         2  2021-06-02 10:53:12   2021-06-02 11:08:30                2
# 100001         2  2021-06-02 10:25:49   2021-06-02 10:40:53                1
# 100002         2  2021-06-02 10:20:53   2021-06-02 10:31:58                1
# 100003         2  2021-06-02 10:37:54   2021-06-02 10:45:28                1
# 100004         2  2021-06-02 10:56:15   2021-06-02 11:03:57                1
# ...          ...                  ...                   ...              ...
# 199995         1  2021-06-03 12:43:47   2021-06-03 12:51:20                1
# 199996         1  2021-06-03 12:55:09   2021-06-03 13:09:48                1
# 199997         1  2021-06-03 12:06:59   2021-06-03 12:24:38                1
# 199998         1  2021-06-03 12:40:13   2021-06-03 12:53:56                1
# 199999         1  2021-06-03 12:59:17   2021-06-03 13:08:28                1
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 100000           1.96           1                  N           238
# 100001           2.89           1                  N           152
# 100002           2.13           1                  N           249
# 100003           0.60           1                  N           142
# 100004           0.78           1                  N            48
# ...               ...         ...                ...           ...
# 199995           1.50           1                  N           142
# 199996           2.40           1                  N           236
# 199997           2.30           1                  N           161
# 199998           1.30           1                  N           164
# 199999           1.20           1                  N           163
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 100000           263             1         11.0    0.0      0.5        1.00
# 100001           239             1         12.5    0.0      0.5        3.16
# 100002           142             1          9.5    0.0      0.5        1.50
# 100003           239             2          6.0    0.0      0.5        0.00
# 100004           100             1          6.5    0.0      0.5        1.96
# ...              ...           ...          ...    ...      ...         ...
# 199995           236             1          8.0    2.5      0.5        1.00
# 199996           166             1         11.5    2.5      0.5        2.00
# 199997            79             1         12.5    2.5      0.5        3.15
# 199998           237             2         10.0    2.5      0.5        0.00
# 199999           143             1          7.5    2.5      0.5        1.00
#
#         tolls_amount  improvement_surcharge  total_amount  \
# 100000           0.0                    0.3         15.30
# 100001           0.0                    0.3         18.96
# 100002           0.0                    0.3         14.30
# 100003           0.0                    0.3          9.30
# 100004           0.0                    0.3         11.76
# ...              ...                    ...           ...
# 199995           0.0                    0.3         12.30
# 199996           0.0                    0.3         16.80
# 199997           0.0                    0.3         18.95
# 199998           0.0                    0.3         13.30
# 199999           0.0                    0.3         11.80
#
#         congestion_surcharge
# 100000                   2.5
# 100001                   2.5
# 100002                   2.5
# 100003                   2.5
# 100004                   2.5
# ...                      ...
# 199995                   2.5
# 199996                   2.5
# 199997                   2.5
# 199998                   2.5
# 199999                   2.5
#
# [100000 rows x 18 columns]

# %%
for taxi in df_iter:
    taxi.head(0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
    print(len(taxi))
# Out:
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 34264

# %%
# !uv add tqdm
# Out:
# Resolved 120 packages in 1ms
# Audited 31 packages in 2ms

# %%
from tqdm import tqdm

# %%
# !uv add ipywidgets jupyterlab_widgets
# Out:
# Resolved 120 packages in 1ms
# Audited 31 packages in 2ms

# %%
taxi_chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists='append', index=False)
# Out:
# 0it [00:00, ?it/s]

# %%
for taxi in df_iter:
    taxi.to_sql(name="yellow_taxi_data", con=engine, if_exists="append", index=False)
